# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np

import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:54, 574KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random
from collections import Counter

threshold = 0.000001
word_count = Counter(int_words)
total_count = len(int_words)
freq_dict = {word: count/total_count for word, count in word_count.items()}
prob_drop = {word: 1 - np.sqrt(threshold/freq_dict[word]) for word in freq_dict}
train_words = [w for w in int_words if random.random() < (1-prob_drop[w])]# The final subsampled word list

print([int_to_vocab[i] for i in train_words[:10]])
# Out:
# ['revolution', 'culottes', 'whilst', 'act', 'destroy', 'a', 'self', 'anarchists', 'archons', 'ruler']

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    rand_index = np.random.randint(1, window_size+1)
    start_index = idx - rand_index if (idx - rand_index) > 0 else 0
    end_index = idx + rand_index if (idx + rand_index) < len(words) else len(words)
    target_words = set(words[start_index:idx] + words[idx+1:end_index+1])
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

to_print = get_batches(int_words, 10, 5)
print(list(to_print))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
#     cost = tf.reduce_mean(loss)
#     optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.1390 0.1980 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.0721 0.1953 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.1160 0.2014 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.0985 0.2119 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.1586 0.2683 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.0837 0.2337 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.0822 0.2761 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.0312 0.2181 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.0796 0.2014 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.0306 0.2020 sec/batch
# Nearest to all: hominidae, flip, wicked, inlay, submissive, bains, grievance, vent,
# Nearest to into: oi, dicrostonyx, disputed, habibullah, tellurium, gospels, doubtless, orford,
# Nearest to been: titan, wilbert, hymns, eastenders, architects, regan, speeded, viva,
# Nearest to three: antidisestablishmentarianism, tyler, disposal, hermite, masonry, napoleon, harren, sesame,
# Nearest to s: hugged, recieved, stokes, yarrow, zephaniah, sceptics, mispronounced, qadhafi,
# Nearest to such: deny, mlas, malfunctioning, pmod, scavenging, ying, performances, narbonne,
# Nearest to be: cares, paymaster, overproduction, experiment, phenols, armadillos, tress, kirk,
# Nearest to first: gayatri, lossless, bracelet, pledge, avoirdupois, mmol, excommunications, motherhood,
# Nearest to resources: cataloging, ruff, yon, hayat, steganography, gaud, roberta, reincarnation,
# Nearest to nobel: affricates, smelt, savage, willfully, diplomacy, scouting, matti, spot,
# Nearest to construction: crna, ille, fringing, coaling, retract, blacklisting, cosmopolitan, minimalism,
# Nearest to arts: bromide, infantry, rugova, compilation, anfield, klux, se, ennio,
# Nearest to running: landen, undefined, pectin, roofs, fondue, burger, sculpture, enamoured,
# Nearest to troops: popularity, stabbing, cascades, damascius, nota, tengri, carnahan, climbed,
# Nearest to shown: tasman, cpt, freaks, sockets, worsen, restyled, eurosceptic, varig,
# Nearest to road: predestination, umbilical, masjid, ordnance, philokalia, consequence, zyklon, aberdare,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.0026 0.2029 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0161 0.1962 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0268 0.1987 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9967 0.2011 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9787 0.1997 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9186 0.1975 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9152 0.2038 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.9310 0.1995 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9166 0.2002 sec/batch
# Epoch 2/10 Iteration: 2000 Avg. Training loss: 4.8515 0.0922 sec/batch
# Nearest to all: hominidae, inlay, wicked, bartleby, vouli, flip, bains, strategy,
# Nearest to into: oi, dicrostonyx, disputed, habibullah, up, thought, tellurium, gospels,
# Nearest to been: titan, wilbert, architects, hymns, philanthropists, cataract, eastenders, regan,
# Nearest to three: tyler, napoleon, antidisestablishmentarianism, sesame, penned, queen, harren, indebtedness,
# Nearest to s: qadhafi, zephaniah, recieved, yarrow, infantile, rewind, msg, tumult,
# Nearest to such: deny, mlas, pmod, malfunctioning, scavenging, unlocked, performances, spaceflights,
# Nearest to be: experiment, cares, paymaster, kirk, lasted, armadillos, hasbro, gagauz,
# Nearest to first: dire, bracelet, quadrants, avoirdupois, relegation, lossless, patriarchs, pledge,
# Nearest to resources: yon, ruff, steganography, cataloging, informally, sportscaster, hayat, roberta,
# Nearest to nobel: affricates, smelt, savage, willfully, diplomacy, spot, scouting, cossa,
# Nearest to construction: crna, blacklisting, coaling, cosmopolitan, fringing, squad, ille, decipherment,
# Nearest to arts: compilation, rugova, infantry, anfield, ennio, se, bromide, dis,
# Nearest to running: undefined, landen, roofs, fondue, startling, pectin, sculpture, burger,
# Nearest to troops: popularity, nota, carnahan, simultaneously, climbed, damascius, advises, tengri,
# Nearest to shown: tasman, cpt, freaks, sockets, zoran, varig, tarsus, worsen,
# Nearest to road: ordnance, umbilical, predestination, masjid, cutscenes, philokalia, brearley, grodd,
# Epoch 2/10 Iteration: 2100 Avg. Training loss: 4.6837 0.2018 sec/batch
# Epoch 2/10 Iteration: 2200 Avg. Training loss: 4.6984 0.1972 sec/batch
# Epoch 2/10 Iteration: 2300 Avg. Training loss: 4.7248 0.1964 sec/batch
# Epoch 2/10 Iteration: 2400 Avg. Training loss: 4.6970 0.1971 sec/batch
# Epoch 2/10 Iteration: 2500 Avg. Training loss: 4.6957 0.2042 sec/batch
# Epoch 2/10 Iteration: 2600 Avg. Training loss: 4.6026 0.1998 sec/batch
# Epoch 2/10 Iteration: 2700 Avg. Training loss: 4.6314 0.1992 sec/batch
# Epoch 2/10 Iteration: 2800 Avg. Training loss: 4.6197 0.1955 sec/batch
# Epoch 2/10 Iteration: 2900 Avg. Training loss: 4.5994 0.1961 sec/batch
# Epoch 2/10 Iteration: 3000 Avg. Training loss: 4.5816 0.1980 sec/batch
# Nearest to all: hominidae, strategy, inlay, flip, shea, wicked, rounded, carnage,
# Nearest to into: oi, disputed, up, dicrostonyx, faith, habibullah, doubtless, tellurium,
# Nearest to been: titan, architects, wilbert, blow, resign, correspondence, cataract, oceangoing,
# Nearest to three: napoleon, antidisestablishmentarianism, tyler, queen, penned, sesame, harren, extension,
# Nearest to s: zephaniah, recieved, warn, yarrow, tumult, qadhafi, infantile, responsibilities,
# Nearest to such: deny, mlas, pmod, unlocked, scavenging, crucial, malfunctioning, restricting,
# Nearest to be: lasted, cares, experiment, completeness, peaks, paymaster, consist, prentice,
# Nearest to first: patriarchs, relegation, pledge, doctor, involve, metrics, dire, bracelet,
# Nearest to resources: informally, details, consequently, steganography, yon, innermost, sportscaster, roberta,
# Nearest to nobel: affricates, smelt, savage, diplomacy, willfully, scouting, tools, spot,
# Nearest to construction: blacklisting, or, coaling, cosmopolitan, electrically, crna, fringing, decipherment,
# Nearest to arts: compilation, ennio, se, infantry, dis, rugova, anfield, design,
# Nearest to running: undefined, roofs, sculpture, participation, fondue, startling, upper, landen,
# Nearest to troops: popularity, expand, nota, simultaneously, damascius, stabbing, climbed, carnahan,
# Nearest to shown: tasman, cpt, tarsus, zoran, total, worsen, eurosceptic, virial,
# Nearest to road: ordnance, cutscenes, masjid, umbilical, brearley, consequence, cdr, intermittently,
# Epoch 2/10 Iteration: 3100 Avg. Training loss: 4.5850 0.1983 sec/batch
# Epoch 2/10 Iteration: 3200 Avg. Training loss: 4.5751 0.1976 sec/batch
# Epoch 2/10 Iteration: 3300 Avg. Training loss: 4.5438 0.1993 sec/batch
# Epoch 2/10 Iteration: 3400 Avg. Training loss: 4.5893 0.2013 sec/batch
# Epoch 2/10 Iteration: 3500 Avg. Training loss: 4.5111 0.1983 sec/batch
# Epoch 2/10 Iteration: 3600 Avg. Training loss: 4.5302 0.1969 sec/batch
# Epoch 2/10 Iteration: 3700 Avg. Training loss: 4.4823 0.1977 sec/batch
# Epoch 2/10 Iteration: 3800 Avg. Training loss: 4.5258 0.2035 sec/batch
# Epoch 2/10 Iteration: 3900 Avg. Training loss: 4.5171 0.4728 sec/batch
# Epoch 3/10 Iteration: 4000 Avg. Training loss: 4.4630 0.2009 sec/batch
# Nearest to all: flip, hominidae, wicked, inlay, strategy, converting, shea, overt,
# Nearest to into: oi, disputed, snyder, indirectly, up, faith, tellurium, habibullah,
# Nearest to been: titan, architects, hymns, consent, cataract, philanthropists, wilbert, resign,
# Nearest to three: napoleon, antidisestablishmentarianism, tyler, queen, nonaligned, molly, scandalous, sesame,
# Nearest to s: yarrow, zephaniah, qadhafi, recieved, stokes, warn, hugged, tumult,
# Nearest to such: deny, mlas, scavenging, pmod, incubated, unlocked, malfunctioning, restricting,
# Nearest to be: completeness, cares, experiment, peaks, exponential, universalism, paymaster, equation,
# Nearest to first: patriarchs, doctor, relegation, mitzvah, dire, avoirdupois, lossless, pledge,
# Nearest to resources: informally, yon, steganography, roberta, mishima, diwan, combustion, opulent,
# Nearest to nobel: affricates, smelt, savage, willfully, diplomacy, matti, aemilius, josef,
# Nearest to construction: blacklisting, electrically, cosmopolitan, coaling, asking, retract, expansive, squad,
# Nearest to arts: compilation, design, ennio, dis, se, infantry, glr, rugova,
# Nearest to running: undefined, roofs, upper, sculpture, cinerama, landen, processor, pectin,
# Nearest to troops: popularity, climbed, stabbing, expand, sector, nota, uneasy, samuel,
# Nearest to shown: cpt, tasman, freaks, worsen, varig, caliph, tarsus, virial,
# Nearest to road: ordnance, masjid, cutscenes, consequence, brearley, indent, intermittently, quicker,
# Epoch 3/10 Iteration: 4100 Avg. Training loss: 4.4090 0.2227 sec/batch
# Epoch 3/10 Iteration: 4200 Avg. Training loss: 4.3733 0.2151 sec/batch
# Epoch 3/10 Iteration: 4300 Avg. Training loss: 4.4365 0.2097 sec/batch
# Epoch 3/10 Iteration: 4400 Avg. Training loss: 4.3869 0.2038 sec/batch
# Epoch 3/10 Iteration: 4500 Avg. Training loss: 4.3787 0.2016 sec/batch
# Epoch 3/10 Iteration: 4600 Avg. Training loss: 4.3641 0.1976 sec/batch
# Epoch 3/10 Iteration: 4700 Avg. Training loss: 4.3742 0.1970 sec/batch
# Epoch 3/10 Iteration: 4800 Avg. Training loss: 4.4304 0.1983 sec/batch
# Epoch 3/10 Iteration: 4900 Avg. Training loss: 4.3628 0.1962 sec/batch
# Epoch 3/10 Iteration: 5000 Avg. Training loss: 4.3622 0.1965 sec/batch
# Nearest to all: flip, incitement, inlay, hominidae, overt, rounded, converting, adhesion,
# Nearest to into: snyder, disputed, oi, tellurium, up, orford, indirectly, habibullah,
# Nearest to been: titan, philanthropists, architects, hymns, consent, alboin, cataract, proclaims,
# Nearest to three: queen, antidisestablishmentarianism, napoleon, tyler, nonaligned, molly, reelected, hermite,
# Nearest to s: stokes, yarrow, zephaniah, tumult, recieved, warn, qadhafi, hugged,
# Nearest to such: deny, mlas, scavenging, outward, koch, incubated, pmod, crucial,
# Nearest to be: completeness, equation, experiment, cares, exponential, arguments, consist, theorem,
# Nearest to first: patriarchs, doctor, bracelet, lossless, avoirdupois, relegation, calmly, dire,
# Nearest to resources: combustion, yon, informally, opulent, steganography, roberta, squads, unlawful,
# Nearest to nobel: affricates, smelt, josef, willfully, savage, matti, aemilius, diplomacy,
# Nearest to construction: blacklisting, electrically, cosmopolitan, expansive, coaling, specify, retract, asking,
# Nearest to arts: compilation, design, ennio, dis, se, bromide, anfield, rugova,
# Nearest to running: undefined, landen, cinerama, sculpture, pectin, roofs, upper, balboa,
# Nearest to troops: climbed, popularity, stabbing, sector, samuel, expand, carnahan, urgently,
# Nearest to shown: cpt, tasman, worsen, freaks, virial, varig, eurosceptic, constants,
# Nearest to road: ordnance, brearley, masjid, cutscenes, indent, portland, designated, aberdare,
# Epoch 3/10 Iteration: 5100 Avg. Training loss: 4.3457 0.2005 sec/batch
# Epoch 3/10 Iteration: 5200 Avg. Training loss: 4.3791 0.1987 sec/batch
# Epoch 3/10 Iteration: 5300 Avg. Training loss: 4.3725 0.1992 sec/batch
# Epoch 3/10 Iteration: 5400 Avg. Training loss: 4.3510 0.1947 sec/batch
# Epoch 3/10 Iteration: 5500 Avg. Training loss: 4.3746 0.1970 sec/batch
# Epoch 3/10 Iteration: 5600 Avg. Training loss: 4.3196 0.1986 sec/batch
# Epoch 3/10 Iteration: 5700 Avg. Training loss: 4.3052 0.1963 sec/batch
# Epoch 3/10 Iteration: 5800 Avg. Training loss: 4.3513 0.1986 sec/batch
# Epoch 4/10 Iteration: 5900 Avg. Training loss: 4.3467 0.0744 sec/batch
# Epoch 4/10 Iteration: 6000 Avg. Training loss: 4.2372 0.1979 sec/batch
# Nearest to all: flip, inlay, overt, incitement, wicked, converting, hominidae, periodization,
# Nearest to into: snyder, oi, disputed, orford, tellurium, indirectly, doubtless, habibullah,
# Nearest to been: titan, hymns, philanthropists, architects, insanely, cataract, alboin, proclaims,
# Nearest to three: queen, tyler, antidisestablishmentarianism, zayas, molly, edouard, http, reelected,
# Nearest to s: yarrow, stokes, zephaniah, hugged, qadhafi, tumult, recieved, supposing,
# Nearest to such: mlas, deny, scavenging, pmod, incubated, outward, neither, koch,
# Nearest to be: completeness, equation, arguments, intramolecular, experiment, primitive, theorem, exponential,
# Nearest to first: patriarchs, doctor, mitzvah, relegation, stan, bracelet, chretien, abbess,
# Nearest to resources: combustion, yon, hayat, steganography, informally, opulent, mishima, details,
# Nearest to nobel: smelt, josef, matti, aemilius, affricates, actor, savage, ustinov,
# Nearest to construction: electrically, blacklisting, expansive, coaling, specify, cosmopolitan, retract, minimalism,
# Nearest to arts: compilation, design, bromide, ennio, anfield, farnsworth, tucker, rugova,
# Nearest to running: undefined, landen, pectin, ziv, roofs, upper, cinerama, processor,
# Nearest to troops: stabbing, climbed, sector, popularity, urgently, samuel, galveston, uneasy,
# Nearest to shown: cpt, tasman, freaks, worsen, constants, virial, generalizations, tricycle,
# Nearest to road: ordnance, masjid, brearley, indent, aberdare, denton, quicker, cutscenes,
# Epoch 4/10 Iteration: 6100 Avg. Training loss: 4.2335 0.2016 sec/batch
# Epoch 4/10 Iteration: 6200 Avg. Training loss: 4.2843 0.1977 sec/batch
# Epoch 4/10 Iteration: 6300 Avg. Training loss: 4.2693 0.1969 sec/batch
# Epoch 4/10 Iteration: 6400 Avg. Training loss: 4.2426 0.1969 sec/batch
# Epoch 4/10 Iteration: 6500 Avg. Training loss: 4.2264 0.1973 sec/batch
# Epoch 4/10 Iteration: 6600 Avg. Training loss: 4.2356 0.1978 sec/batch
# Epoch 4/10 Iteration: 6700 Avg. Training loss: 4.2255 0.1958 sec/batch
# Epoch 4/10 Iteration: 6800 Avg. Training loss: 4.2222 0.2015 sec/batch
# Epoch 4/10 Iteration: 6900 Avg. Training loss: 4.2260 0.2297 sec/batch
# Epoch 4/10 Iteration: 7000 Avg. Training loss: 4.2392 0.2169 sec/batch
# Nearest to all: flip, rundstedt, incitement, submissive, inlay, converting, overt, hominidae,
# Nearest to into: snyder, disputed, oi, orford, tellurium, indirectly, feudal, doubtless,
# Nearest to been: titan, philanthropists, insanely, alboin, hymns, cataract, architects, manufacturing,
# Nearest to three: queen, kg, zayas, saigon, harren, http, edouard, tyler,
# Nearest to s: yarrow, stokes, hugged, zephaniah, qadhafi, supposing, tumult, warn,
# Nearest to such: mlas, scavenging, outward, deny, incubated, malfunctioning, koch, unlocked,
# Nearest to be: completeness, equation, arguments, intramolecular, exponential, primitive, experiment, theorem,
# Nearest to first: patriarchs, mitzvah, avoirdupois, doctor, bracelet, lossless, abbess, insolvency,
# Nearest to resources: combustion, steganography, mishima, diwan, tissues, details, yon, squads,
# Nearest to nobel: josef, smelt, matti, savage, barker, aemilius, organist, affricates,
# Nearest to construction: electrically, expansive, coaling, blacklisting, specify, cosmopolitan, minimalism, avars,
# Nearest to arts: compilation, design, bromide, ennio, tucker, farnsworth, anfield, sociology,
# Nearest to running: undefined, pectin, ziv, landen, roofs, processor, recycle, cinerama,
# Nearest to troops: sector, climbed, urgently, stabbing, uneasy, franco, elected, galveston,
# Nearest to shown: cpt, tasman, freaks, constants, worsen, virial, generalizations, mysql,
# Nearest to road: ordnance, brearley, indent, aberdare, masjid, averroes, denton, portland,
# Epoch 4/10 Iteration: 7100 Avg. Training loss: 4.2147 10.8472 sec/batch
# Epoch 4/10 Iteration: 7200 Avg. Training loss: 4.2307 14.0393 sec/batch
# Epoch 4/10 Iteration: 7300 Avg. Training loss: 4.2017 0.6567 sec/batch
# Epoch 4/10 Iteration: 7400 Avg. Training loss: 4.2010 2.9910 sec/batch
# Epoch 4/10 Iteration: 7500 Avg. Training loss: 4.2004 10.5224 sec/batch
# Epoch 4/10 Iteration: 7600 Avg. Training loss: 4.1596 12.3105 sec/batch
# Epoch 4/10 Iteration: 7700 Avg. Training loss: 4.2228 0.4338 sec/batch
# Epoch 4/10 Iteration: 7800 Avg. Training loss: 4.1715 3.8447 sec/batch
# Epoch 5/10 Iteration: 7900 Avg. Training loss: 4.1750 19.6661 sec/batch
# Epoch 5/10 Iteration: 8000 Avg. Training loss: 4.0903 0.4229 sec/batch
# Nearest to all: flip, converting, rundstedt, inlay, submissive, direct, incitement, periodization,
# Nearest to into: snyder, oi, orford, tellurium, disputed, indirectly, ardant, inertness,
# Nearest to been: titan, revolvers, hymns, cataract, rescheduled, philanthropists, architects, alboin,
# Nearest to three: queen, kg, two, tauroctony, saigon, edouard, zayas, four,
# Nearest to s: yarrow, zephaniah, stokes, shockley, hugged, awry, supposing, qadhafi,
# Nearest to such: mlas, scavenging, deny, neither, incubated, outpaced, outward, quince,
# Nearest to be: completeness, intramolecular, arguments, cares, primitive, equation, usemodwiki, formulation,
# Nearest to first: patriarchs, mitzvah, hawick, stan, insolvency, avoirdupois, abbess, loot,
# Nearest to resources: combustion, squads, roberta, mishima, steganography, informally, opulent, details,
# Nearest to nobel: josef, smelt, matti, organist, diplomat, savage, aemilius, ustinov,
# Nearest to construction: coaling, electrically, minimalism, expansive, blacklisting, avars, loosening, permian,
# Nearest to arts: compilation, design, bromide, tucker, farnsworth, anfield, dis, etheridge,
# Nearest to running: undefined, pectin, processor, ziv, landen, roofs, trie, recycle,
# Nearest to troops: sector, skj, uneasy, urgently, franco, climbed, elected, liberalisation,
# Nearest to shown: cpt, tasman, freaks, constants, raccoons, virial, worsen, generalizations,
# Nearest to road: indent, ordnance, aberdare, brearley, denton, averroes, gre, portland,
# Epoch 5/10 Iteration: 8100 Avg. Training loss: 4.0758 3.7365 sec/batch
# Epoch 5/10 Iteration: 8200 Avg. Training loss: 4.1337 1.9674 sec/batch
# Epoch 5/10 Iteration: 8300 Avg. Training loss: 4.1123 0.7909 sec/batch
# Epoch 5/10 Iteration: 8400 Avg. Training loss: 4.0712 1.4519 sec/batch
# Epoch 5/10 Iteration: 8500 Avg. Training loss: 4.0599 0.2224 sec/batch
# Epoch 5/10 Iteration: 8600 Avg. Training loss: 4.0733 0.2159 sec/batch
# Epoch 5/10 Iteration: 8700 Avg. Training loss: 4.0845 0.2154 sec/batch
# Epoch 5/10 Iteration: 8800 Avg. Training loss: 4.0881 0.2174 sec/batch
# Epoch 5/10 Iteration: 8900 Avg. Training loss: 4.0433 0.2083 sec/batch
# Epoch 5/10 Iteration: 9000 Avg. Training loss: 4.0889 0.2045 sec/batch
# Nearest to all: flip, rundstedt, inlay, submissive, converting, direct, incitement, overt,
# Nearest to into: snyder, orford, disputed, oily, oi, tellurium, feudal, large,
# Nearest to been: titan, revolvers, philanthropists, armenian, cataract, alboin, insanely, finding,
# Nearest to three: kg, two, queen, tauroctony, harren, zayas, saigon, four,
# Nearest to s: stokes, zephaniah, awry, yarrow, shockley, hugged, longing, supposing,
# Nearest to such: mlas, scavenging, deny, unlocked, malfunctioning, outward, koch, outpaced,
# Nearest to be: completeness, intramolecular, primitive, cares, arguments, simplify, usemodwiki, equation,
# Nearest to first: patriarchs, mitzvah, hawick, avoirdupois, excommunications, corresponded, homeomorphisms, abbess,
# Nearest to resources: combustion, roberta, details, mishima, cnc, diwan, tab, squads,
# Nearest to nobel: josef, organist, matti, smelt, biochemist, barker, savage, diplomat,
# Nearest to construction: electrically, coaling, minimalism, permian, expansive, ministerio, avars, loosening,
# Nearest to arts: compilation, design, bromide, tucker, etheridge, dis, anfield, farnsworth,
# Nearest to running: undefined, ziv, pectin, processor, landen, adf, javascript, roofs,
# Nearest to troops: sector, skj, franco, naval, uneasy, urgently, humanitarian, union,
# Nearest to shown: cpt, constants, tasman, freaks, generalizations, raccoons, virial, worsen,
# Nearest to road: indent, aberdare, brearley, denton, portland, ordnance, zyklon, averroes,
# Epoch 5/10 Iteration: 9100 Avg. Training loss: 4.0799 0.2045 sec/batch
# Epoch 5/10 Iteration: 9200 Avg. Training loss: 4.0692 0.2164 sec/batch
# Epoch 5/10 Iteration: 9300 Avg. Training loss: 4.0653 0.2049 sec/batch
# Epoch 5/10 Iteration: 9400 Avg. Training loss: 4.0950 0.1989 sec/batch
# Epoch 5/10 Iteration: 9500 Avg. Training loss: 4.0720 0.1969 sec/batch
# Epoch 5/10 Iteration: 9600 Avg. Training loss: 4.0437 0.2016 sec/batch
# Epoch 5/10 Iteration: 9700 Avg. Training loss: 4.0457 0.2032 sec/batch
# Epoch 6/10 Iteration: 9800 Avg. Training loss: 4.0563 0.0621 sec/batch
# Epoch 6/10 Iteration: 9900 Avg. Training loss: 3.9742 0.2045 sec/batch
# Epoch 6/10 Iteration: 10000 Avg. Training loss: 3.9719 0.2236 sec/batch
# Nearest to all: flip, enumerates, converting, periodization, inlay, rundstedt, direct, submissive,
# Nearest to into: snyder, orford, disputed, feudal, oi, large, tellurium, oily,
# Nearest to been: titan, revolvers, oceangoing, armenian, rescheduled, was, cataract, finding,
# Nearest to three: two, kg, four, edouard, francesco, higginbotham, zero, coffey,
# Nearest to s: yarrow, hugged, stokes, shockley, zephaniah, longing, awry, qadhafi,
# Nearest to such: mlas, scavenging, deny, outpaced, malfunctioning, unlocked, quince, crucial,
# Nearest to be: primitive, intramolecular, completeness, cares, arguments, usemodwiki, simplify, inductance,
# Nearest to first: stan, mitzvah, patriarchs, excommunications, hawick, insolvency, jts, lossless,
# Nearest to resources: roberta, combustion, details, cnc, thatched, mishima, protostomes, tabs,
# Nearest to nobel: josef, organist, biochemist, matti, smelt, barker, diplomat, furtado,
# Nearest to construction: electrically, coaling, minimalism, permian, expansive, loosening, ministerio, avars,
# Nearest to arts: compilation, design, bromide, tucker, dis, farnsworth, etheridge, adidas,
# Nearest to running: undefined, processor, ziv, pectin, javascript, roofs, adf, landen,
# Nearest to troops: sector, franco, uneasy, skj, payment, naval, urgently, reconquest,
# Nearest to shown: cpt, freaks, raccoons, tasman, constants, virial, mysql, australopithecines,
# Nearest to road: indent, aberdare, ordnance, denton, portland, projectiles, gre, eastwood,
# Epoch 6/10 Iteration: 10100 Avg. Training loss: 4.0162 0.2200 sec/batch
# Epoch 6/10 Iteration: 10200 Avg. Training loss: 3.9779 0.2112 sec/batch
# Epoch 6/10 Iteration: 10300 Avg. Training loss: 3.9592 0.2154 sec/batch
# Epoch 6/10 Iteration: 10400 Avg. Training loss: 3.9405 0.2036 sec/batch
# Epoch 6/10 Iteration: 10500 Avg. Training loss: 3.9609 0.2051 sec/batch
# Epoch 6/10 Iteration: 10600 Avg. Training loss: 3.9344 0.3403 sec/batch
# Epoch 6/10 Iteration: 10700 Avg. Training loss: 3.9382 0.2121 sec/batch
# Epoch 6/10 Iteration: 10800 Avg. Training loss: 3.9851 0.2182 sec/batch
# Epoch 6/10 Iteration: 10900 Avg. Training loss: 3.9578 0.2157 sec/batch
# Epoch 6/10 Iteration: 11000 Avg. Training loss: 3.9264 0.2209 sec/batch
# Nearest to all: flip, inlay, rundstedt, enumerates, converting, periodization, chilperic, incitement,
# Nearest to into: snyder, orford, oily, disputed, feudal, vrije, indirectly, faith,
# Nearest to been: titan, finding, rescheduled, philanthropists, was, revolvers, zwicker, armenian,
# Nearest to three: kg, two, coffey, falconer, four, tanker, holmes, clifford,
# Nearest to s: stokes, hugged, shockley, zephaniah, awry, mensa, longing, unsure,
# Nearest to such: mlas, unlocked, scavenging, outpaced, deny, malfunctioning, pmod, lc,
# Nearest to be: intramolecular, cares, primitive, completeness, inductance, arguments, simplify, phenols,
# Nearest to first: mitzvah, excommunications, patriarchs, jts, homeomorphisms, hawick, involve, insolvency,
# Nearest to resources: combustion, roberta, thatched, protostomes, details, tabs, cnc, tab,
# Nearest to nobel: josef, organist, biochemist, matti, furtado, smelt, barker, diplomat,
# Nearest to construction: electrically, coaling, minimalism, ministerio, loosening, visualize, permian, expansive,
# Nearest to arts: compilation, design, bromide, tucker, farnsworth, adidas, dis, tridactyla,
# Nearest to running: undefined, pectin, adf, ziv, javascript, trigger, roofs, processor,
# Nearest to troops: sector, skj, uneasy, payment, franco, naval, reconquest, mutinied,
# Nearest to shown: cpt, freaks, constants, tasman, virial, mysql, raccoons, generalizations,
# Nearest to road: indent, aberdare, portland, denton, projectiles, gre, ordnance, tallapoosa,
# Epoch 6/10 Iteration: 11100 Avg. Training loss: 3.9746 0.2262 sec/batch
# Epoch 6/10 Iteration: 11200 Avg. Training loss: 3.9788 0.2084 sec/batch
# Epoch 6/10 Iteration: 11300 Avg. Training loss: 3.9896 0.2222 sec/batch
# Epoch 6/10 Iteration: 11400 Avg. Training loss: 4.0092 0.2206 sec/batch
# Epoch 6/10 Iteration: 11500 Avg. Training loss: 3.9393 0.2073 sec/batch
# Epoch 6/10 Iteration: 11600 Avg. Training loss: 3.9649 0.2102 sec/batch
# Epoch 6/10 Iteration: 11700 Avg. Training loss: 3.8998 0.2003 sec/batch
# Epoch 7/10 Iteration: 11800 Avg. Training loss: 3.9293 0.1530 sec/batch
# Epoch 7/10 Iteration: 11900 Avg. Training loss: 3.8786 0.1998 sec/batch
# Epoch 7/10 Iteration: 12000 Avg. Training loss: 3.8195 0.2001 sec/batch
# Nearest to all: enumerates, flip, inlay, periodization, rundstedt, curia, incitement, honest,
# Nearest to into: snyder, orford, oily, large, inertness, ardant, bulgakov, disputed,
# Nearest to been: titan, rescheduled, finding, cataract, was, oceangoing, zwicker, armenian,
# Nearest to three: kg, two, four, falconer, holmes, zero, lb, tanker,
# Nearest to s: hugged, shockley, stokes, awry, longing, zephaniah, connector, osama,
# Nearest to such: mlas, scavenging, unlocked, outpaced, lc, crucial, deny, pmod,
# Nearest to be: cares, primitive, intramolecular, inductance, completeness, phenols, arguments, dependencies,
# Nearest to first: excommunications, patriarchs, mitzvah, hawick, insolvency, separation, jts, involve,
# Nearest to resources: roberta, thatched, details, toppling, tabs, combustion, protostomes, mishima,
# Nearest to nobel: josef, biochemist, organist, matti, furtado, diplomat, ernst, smelt,
# Nearest to construction: electrically, coaling, minimalism, loosening, heliport, ministerio, bearshare, avars,
# Nearest to arts: design, compilation, bromide, tucker, wagon, etheridge, tridactyla, dis,
# Nearest to running: undefined, ziv, adf, pectin, roofs, javascript, trigger, processor,
# Nearest to troops: skj, uneasy, mutinied, sector, reconquest, payment, franco, urgently,
# Nearest to shown: cpt, freaks, constants, raccoons, mysql, australopithecines, generalizations, inanimate,
# Nearest to road: indent, aberdare, projectiles, portland, tallapoosa, denton, gre, kona,
# Epoch 7/10 Iteration: 12100 Avg. Training loss: 3.9017 0.8527 sec/batch
# Epoch 7/10 Iteration: 12200 Avg. Training loss: 3.8917 0.2059 sec/batch
# Epoch 7/10 Iteration: 12300 Avg. Training loss: 3.8580 0.2187 sec/batch
# Epoch 7/10 Iteration: 12400 Avg. Training loss: 3.8446 0.2140 sec/batch
# Epoch 7/10 Iteration: 12500 Avg. Training loss: 3.8824 0.2075 sec/batch
# Epoch 7/10 Iteration: 12600 Avg. Training loss: 3.8886 0.2055 sec/batch
# Epoch 7/10 Iteration: 12700 Avg. Training loss: 3.8469 0.2003 sec/batch
# Epoch 7/10 Iteration: 12800 Avg. Training loss: 3.8576 0.2035 sec/batch
# Epoch 7/10 Iteration: 12900 Avg. Training loss: 3.8635 0.2109 sec/batch
# Epoch 7/10 Iteration: 13000 Avg. Training loss: 3.9056 0.2090 sec/batch
# Nearest to all: enumerates, flip, inlay, periodization, honest, lutherans, direct, shamanic,
# Nearest to into: snyder, orford, oily, feudal, inertness, disputed, bulgakov, large,
# Nearest to been: titan, finding, revolvers, cataract, was, gravel, armenian, jima,
# Nearest to three: kg, two, four, tanker, lb, zero, falconer, holmes,
# Nearest to s: hugged, shockley, stokes, mensa, longing, awry, revolve, connector,
# Nearest to such: mlas, unlocked, scavenging, outpaced, lc, crucial, incubated, malfunctioning,
# Nearest to be: intramolecular, primitive, cares, completeness, phenols, inductance, arguments, reactivity,
# Nearest to first: excommunications, patriarchs, involve, mitzvah, hawick, jts, homeomorphisms, separation,
# Nearest to resources: roberta, thatched, details, protostomes, combustion, tabs, toppling, tab,
# Nearest to nobel: josef, biochemist, organist, smelt, matti, furtado, albarn, talleyrand,
# Nearest to construction: electrically, coaling, minimalism, loosening, discordian, bearshare, intact, sovereigns,
# Nearest to arts: compilation, design, bromide, tucker, tridactyla, wagon, etheridge, adidas,
# Nearest to running: undefined, adf, ziv, berners, trigger, marian, schalk, pectin,
# Nearest to troops: uneasy, mutinied, reconquest, skj, naval, fractures, damascius, intersected,
# Nearest to shown: cpt, freaks, mysql, constants, australopithecines, raccoons, generalizations, virial,
# Nearest to road: indent, portland, projectiles, engined, aberdare, tallapoosa, eastwood, denton,
# Epoch 7/10 Iteration: 13100 Avg. Training loss: 3.8495 0.2043 sec/batch
# Epoch 7/10 Iteration: 13200 Avg. Training loss: 3.8713 0.2019 sec/batch
# Epoch 7/10 Iteration: 13300 Avg. Training loss: 3.9577 0.2186 sec/batch
# Epoch 7/10 Iteration: 13400 Avg. Training loss: 3.8649 0.2146 sec/batch
# Epoch 7/10 Iteration: 13500 Avg. Training loss: 3.8215 0.1990 sec/batch
# Epoch 7/10 Iteration: 13600 Avg. Training loss: 3.8625 0.2010 sec/batch
# Epoch 8/10 Iteration: 13700 Avg. Training loss: 3.8589 0.0443 sec/batch
# Epoch 8/10 Iteration: 13800 Avg. Training loss: 3.7847 0.2000 sec/batch
# Epoch 8/10 Iteration: 13900 Avg. Training loss: 3.7450 0.2000 sec/batch
# Epoch 8/10 Iteration: 14000 Avg. Training loss: 3.7996 0.1997 sec/batch
# Nearest to all: enumerates, flip, periodization, inlay, incitement, curia, lutherans, chilperic,
# Nearest to into: snyder, orford, large, feudal, inertness, bulgakov, oily, vrije,
# Nearest to been: titan, jima, rescheduled, zwicker, was, finding, revolvers, gravel,
# Nearest to three: two, kg, four, zero, one, lb, tanker, holmes,
# Nearest to s: hugged, mensa, revolve, raison, shockley, longing, awry, connector,
# Nearest to such: mlas, unlocked, lc, scavenging, outpaced, incubated, crucial, decried,
# Nearest to be: intramolecular, cares, primitive, phenols, inductance, reactivity, completeness, dependencies,
# Nearest to first: excommunications, hawick, patriarchs, involve, mitzvah, insolvency, jts, kelso,
# Nearest to resources: roberta, thatched, toppling, tabs, potable, burkina, yaoi, details,
# Nearest to nobel: biochemist, josef, organist, furtado, smelt, matti, trey, recipient,
# Nearest to construction: electrically, coaling, was, discordian, intact, heliport, sovereigns, loosening,
# Nearest to arts: design, bromide, compilation, etheridge, tucker, wagon, shou, fort,
# Nearest to running: undefined, adf, berners, ziv, pectin, panzer, javascript, enhancements,
# Nearest to troops: uneasy, mutinied, fractures, skj, forces, reconquest, naval, guimar,
# Nearest to shown: cpt, freaks, constants, australopithecines, mysql, raccoons, generalizations, virial,
# Nearest to road: indent, projectiles, tallapoosa, portland, kona, engined, eastwood, hubs,
# Epoch 8/10 Iteration: 14100 Avg. Training loss: 3.8165 0.2082 sec/batch
# Epoch 8/10 Iteration: 14200 Avg. Training loss: 3.7716 0.2004 sec/batch
# Epoch 8/10 Iteration: 14300 Avg. Training loss: 3.7458 0.2027 sec/batch
# Epoch 8/10 Iteration: 14400 Avg. Training loss: 3.8001 0.2029 sec/batch
# Epoch 8/10 Iteration: 14500 Avg. Training loss: 3.7983 0.2030 sec/batch
# Epoch 8/10 Iteration: 14600 Avg. Training loss: 3.8065 0.2024 sec/batch
# Epoch 8/10 Iteration: 14700 Avg. Training loss: 3.8050 0.2025 sec/batch
# Epoch 8/10 Iteration: 14800 Avg. Training loss: 3.7861 0.2028 sec/batch
# Epoch 8/10 Iteration: 14900 Avg. Training loss: 3.7984 0.2025 sec/batch
# Epoch 8/10 Iteration: 15000 Avg. Training loss: 3.7710 0.2031 sec/batch
# Nearest to all: enumerates, flip, periodization, inlay, incitement, lutherans, chilperic, direct,
# Nearest to into: snyder, orford, large, oily, feudal, alpacas, disputed, inertness,
# Nearest to been: titan, finding, revolvers, jima, armenian, zwicker, rescheduled, cataract,
# Nearest to three: two, kg, four, tanker, zero, one, lb, five,
# Nearest to s: hugged, revolve, mensa, longing, unsure, shockley, connector, rhyming,
# Nearest to such: lc, unlocked, mlas, scavenging, outpaced, incubated, multiplexed, crucial,
# Nearest to be: cares, intramolecular, primitive, dependencies, phenols, inductance, real, reactivity,
# Nearest to first: excommunications, separation, involve, patriarchs, jts, mitzvah, hawick, intercollegiate,
# Nearest to resources: roberta, thatched, toppling, tabs, details, yaoi, mishima, comedies,
# Nearest to nobel: biochemist, josef, smelt, organist, furtado, matti, vries, trey,
# Nearest to construction: electrically, coaling, was, powerhouse, intact, shipyard, discordian, sovereigns,
# Nearest to arts: design, compilation, bromide, tucker, wagon, etheridge, fort, fruity,
# Nearest to running: undefined, adf, rework, drops, schalk, hartenstein, panzer, marian,
# Nearest to troops: uneasy, mutinied, reconquest, naval, skj, forces, fractures, hafizullah,
# Nearest to shown: freaks, cpt, constants, generalizations, mysql, australopithecines, arlo, raccoons,
# Nearest to road: indent, portland, tallapoosa, projectiles, aberdare, engined, ncaa, backs,
# Epoch 8/10 Iteration: 15100 Avg. Training loss: 3.7900 0.2065 sec/batch
# Epoch 8/10 Iteration: 15200 Avg. Training loss: 3.8338 0.2013 sec/batch
# Epoch 8/10 Iteration: 15300 Avg. Training loss: 3.8401 0.1982 sec/batch
# Epoch 8/10 Iteration: 15400 Avg. Training loss: 3.7755 0.2004 sec/batch
# Epoch 8/10 Iteration: 15500 Avg. Training loss: 3.8025 0.2009 sec/batch
# Epoch 8/10 Iteration: 15600 Avg. Training loss: 3.7891 1.4917 sec/batch
# Epoch 9/10 Iteration: 15700 Avg. Training loss: 3.8021 0.1334 sec/batch
# Epoch 9/10 Iteration: 15800 Avg. Training loss: 3.7256 0.7859 sec/batch
# Epoch 9/10 Iteration: 15900 Avg. Training loss: 3.6998 0.2225 sec/batch
# Epoch 9/10 Iteration: 16000 Avg. Training loss: 3.7202 0.9537 sec/batch
# Nearest to all: periodization, enumerates, flip, inlay, lutherans, msil, szil, chilperic,
# Nearest to into: snyder, orford, oily, osaka, doubtless, large, alpacas, octahedron,
# Nearest to been: titan, jima, finding, zwicker, revolvers, rescheduled, hymns, cataract,
# Nearest to three: two, kg, zero, four, one, five, tanker, lb,
# Nearest to s: hugged, revolve, longing, mensa, gorillas, raison, rhyming, shockley,
# Nearest to such: lc, mlas, unlocked, scavenging, multiplexed, outpaced, incubated, decried,
# Nearest to be: intramolecular, cares, reactivity, phenols, primitive, inductance, dependencies, infamously,
# Nearest to first: excommunications, separation, jts, intercollegiate, hawick, mitzvah, patriarchs, involve,
# Nearest to resources: roberta, thatched, toppling, tabs, yaoi, mishima, comedies, potable,
# Nearest to nobel: biochemist, josef, furtado, smelt, recipient, matti, organist, trey,
# Nearest to construction: was, electrically, coaling, shipyard, powerhouse, discordian, tractors, sovereigns,
# Nearest to arts: design, bromide, compilation, etheridge, tucker, wagon, tridactyla, shou,
# Nearest to running: undefined, adf, drops, hartenstein, landen, rework, panzer, schalk,
# Nearest to troops: uneasy, mutinied, fractures, guimar, naval, evstafiev, ritualised, skj,
# Nearest to shown: cpt, freaks, generalizations, mysql, arlo, constants, pde, virial,
# Nearest to road: indent, tallapoosa, portland, kona, projectiles, canc, ncaa, backs,
# Epoch 9/10 Iteration: 16100 Avg. Training loss: 3.7513 0.2112 sec/batch
# Epoch 9/10 Iteration: 16200 Avg. Training loss: 3.7078 0.2249 sec/batch
# Epoch 9/10 Iteration: 16300 Avg. Training loss: 3.7255 0.2130 sec/batch
# Epoch 9/10 Iteration: 16400 Avg. Training loss: 3.7253 0.2057 sec/batch
# Epoch 9/10 Iteration: 16500 Avg. Training loss: 3.7432 0.2009 sec/batch
# Epoch 9/10 Iteration: 16600 Avg. Training loss: 3.6971 0.2015 sec/batch
# Epoch 9/10 Iteration: 16700 Avg. Training loss: 3.7409 0.2249 sec/batch
# Epoch 9/10 Iteration: 16800 Avg. Training loss: 3.7438 0.2057 sec/batch
# Epoch 9/10 Iteration: 16900 Avg. Training loss: 3.7622 0.2012 sec/batch
# Epoch 9/10 Iteration: 17000 Avg. Training loss: 3.7009 0.1971 sec/batch
# Nearest to all: periodization, enumerates, flip, lutherans, incitement, inlay, msil, chilperic,
# Nearest to into: snyder, orford, alpacas, doubtless, oily, limes, osaka, feudal,
# Nearest to been: finding, titan, jima, zwicker, hymns, cataract, armenian, embellished,
# Nearest to three: two, kg, four, one, zero, five, tanker, lb,
# Nearest to s: hugged, revolve, shockley, mensa, pinchcliffe, raison, rhyming, longing,
# Nearest to such: unlocked, lc, multiplexed, mlas, koch, scavenging, codings, outpaced,
# Nearest to be: cares, intramolecular, primitive, dependencies, inductance, phenols, gagauz, reactivity,
# Nearest to first: excommunications, jts, faithfully, hawick, involve, mitzvah, patriarchs, yeti,
# Nearest to resources: roberta, tabs, toppling, thatched, yaoi, comedies, marxists, interviews,
# Nearest to nobel: biochemist, josef, smelt, furtado, ramesh, trey, matti, organist,
# Nearest to construction: electrically, coaling, was, powerhouse, shipyard, intact, tractors, discordian,
# Nearest to arts: design, bromide, compilation, tucker, wagon, etheridge, fruity, tridactyla,
# Nearest to running: undefined, adf, drops, javascript, rework, rcr, hartenstein, panzer,
# Nearest to troops: evstafiev, uneasy, mutinied, hafizullah, guimar, naval, forces, fractures,
# Nearest to shown: cpt, freaks, arlo, mysql, generalizations, baptists, pde, constants,
# Nearest to road: indent, portland, tallapoosa, canc, kona, ncaa, aberdare, backs,
# Epoch 9/10 Iteration: 17100 Avg. Training loss: 3.7575 0.2013 sec/batch
# Epoch 9/10 Iteration: 17200 Avg. Training loss: 3.7721 1.5427 sec/batch
# Epoch 9/10 Iteration: 17300 Avg. Training loss: 3.7845 0.1940 sec/batch
# Epoch 9/10 Iteration: 17400 Avg. Training loss: 3.6729 0.2157 sec/batch
# Epoch 9/10 Iteration: 17500 Avg. Training loss: 3.7541 0.2124 sec/batch
# Epoch 10/10 Iteration: 17600 Avg. Training loss: 3.7304 0.0285 sec/batch
# Epoch 10/10 Iteration: 17700 Avg. Training loss: 3.6850 0.2082 sec/batch
# Epoch 10/10 Iteration: 17800 Avg. Training loss: 3.6942 0.2000 sec/batch
# Epoch 10/10 Iteration: 17900 Avg. Training loss: 3.6721 0.2061 sec/batch
# Epoch 10/10 Iteration: 18000 Avg. Training loss: 3.6959 0.2038 sec/batch
# Nearest to all: periodization, enumerates, flip, msil, inlay, szil, lutherans, chilperic,
# Nearest to into: snyder, orford, doubtless, alpacas, osaka, vrije, large, nordisk,
# Nearest to been: jima, finding, titan, hymns, zwicker, rescheduled, monkeys, embellished,
# Nearest to three: two, four, kg, zero, one, five, tanker, nine,
# Nearest to s: hugged, revolve, connector, mensa, shockley, unsure, limp, awry,
# Nearest to such: lc, multiplexed, unlocked, mlas, outpaced, october, codings, renouf,
# Nearest to be: intramolecular, cares, phenols, reactivity, dependencies, infamously, inductance, depended,
# Nearest to first: excommunications, intercollegiate, hawick, expellees, patriarchs, involve, faithfully, insolvency,
# Nearest to resources: roberta, tabs, toppling, thatched, comedies, interviews, woodland, arable,
# Nearest to nobel: biochemist, josef, trey, furtado, agnelli, smelt, matti, organist,
# Nearest to construction: electrically, coaling, powerhouse, was, shipyard, tractors, discordian, heliport,
# Nearest to arts: design, bromide, shou, compilation, etheridge, fruity, sculpture, wagon,
# Nearest to running: undefined, adf, drops, rcr, panzer, rework, pectin, hartenstein,
# Nearest to troops: evstafiev, mutinied, uneasy, hafizullah, fractures, guimar, forces, jalisco,
# Nearest to shown: freaks, cpt, generalizations, arlo, mysql, pde, baptists, constants,
# Nearest to road: indent, canc, tallapoosa, portland, aberdare, kona, foot, ncaa,
# Epoch 10/10 Iteration: 18100 Avg. Training loss: 3.6920 0.2011 sec/batch
# Epoch 10/10 Iteration: 18200 Avg. Training loss: 3.6449 0.1978 sec/batch
# Epoch 10/10 Iteration: 18300 Avg. Training loss: 3.6812 0.1993 sec/batch
# Epoch 10/10 Iteration: 18400 Avg. Training loss: 3.6848 0.2017 sec/batch
# Epoch 10/10 Iteration: 18500 Avg. Training loss: 3.6884 0.2030 sec/batch
# Epoch 10/10 Iteration: 18600 Avg. Training loss: 3.7359 0.1980 sec/batch
# Epoch 10/10 Iteration: 18700 Avg. Training loss: 3.7188 0.2043 sec/batch
# Epoch 10/10 Iteration: 18800 Avg. Training loss: 3.6973 0.7034 sec/batch
# Epoch 10/10 Iteration: 18900 Avg. Training loss: 3.7259 0.2187 sec/batch
# Epoch 10/10 Iteration: 19000 Avg. Training loss: 3.6525 0.2370 sec/batch
# Nearest to all: enumerates, periodization, flip, msil, lutherans, szil, incitement, correlates,
# Nearest to into: snyder, orford, vrije, alpacas, doubtless, osaka, limes, oily,
# Nearest to been: finding, jima, titan, porch, revolvers, unlikely, monkeys, cocktail,
# Nearest to three: two, four, five, one, zero, kg, tanker, seven,
# Nearest to s: revolve, shockley, connector, that, hugged, mensa, awry, pinchcliffe,
# Nearest to such: lc, unlocked, outpaced, multiplexed, on, mlas, crucial, koch,
# Nearest to be: cares, intramolecular, dependencies, phenols, infamously, gagauz, primitive, depended,
# Nearest to first: faithfully, excommunications, patriarchs, involve, separation, combatting, diminished, mitzvah,
# Nearest to resources: roberta, tabs, toppling, thatched, interviews, comedies, murmur, mishima,
# Nearest to nobel: biochemist, smelt, josef, trey, matti, agnelli, philo, ramesh,
# Nearest to construction: coaling, was, powerhouse, electrically, tractors, shipyard, finsbury, discordian,
# Nearest to arts: design, bromide, shou, compilation, etheridge, tucker, fruity, tridactyla,
# Nearest to running: undefined, adf, drops, pectin, lash, marian, rcr, hartenstein,
# Nearest to troops: mutinied, evstafiev, hafizullah, uneasy, fractures, forces, guimar, ritualised,
# Nearest to shown: arlo, generalizations, freaks, cpt, baptists, mysql, foal, bitkeeper,
# Nearest to road: indent, portland, canc, meatballwiki, tallapoosa, ncaa, neighborhoods, gre,
# Epoch 10/10 Iteration: 19100 Avg. Training loss: 3.7180 0.2296 sec/batch
# Epoch 10/10 Iteration: 19200 Avg. Training loss: 3.7346 0.2430 sec/batch
# Epoch 10/10 Iteration: 19300 Avg. Training loss: 3.6493 0.2324 sec/batch
# Epoch 10/10 Iteration: 19400 Avg. Training loss: 3.6752 0.2170 sec/batch
# Epoch 10/10 Iteration: 19500 Avg. Training loss: 3.7012 0.2087 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
